# %%
# !pip install simplified_scrapy

# %%
import simplified_scrapy

# %%
import requests
from simplified_scrapy.simplified_doc import SimplifiedDoc
import pandas as pd

data_info = []

def data_select(url):
    
  source = requests.get(url).text
  doc = SimplifiedDoc(source)
  infos = doc.getElements('div', attr='class', value='favorite dui-menu-item')

  for info in infos:
    if info:
        p_url = info['data-item-url']
        product = info['data-item-name']
        price = info['data-price']
        score  = info['data-review-avg']
        data_info.append([p_url, product, price, score])

data_select('https://search.rakuten.co.jp/search/mall/air+purifier/')
data_select('https://search.rakuten.co.jp/search/mall/air+purifier/?p=2')

df = pd.DataFrame(data_info)
df.columns = ['url', 'description', 'price', 'score']
df.head(20)
# Out:
#                                                   url  \
# 0   https://grp07.ias.rakuten.co.jp/redirect_rpp/?...
# 1   https://grp07.ias.rakuten.co.jp/redirect_rpp/?...
# 2   https://grp07.ias.rakuten.co.jp/redirect_rpp/?...
# 3    https://item.rakuten.co.jp/xiaomiofficial/00018/
# 4    https://item.rakuten.co.jp/xiaomiofficial/00017/
# 5     https://item.rakuten.co.jp/roomy/ecl14oct28e01/
# 6        https://item.rakuten.co.jp/plywood/08637004/
# 7      https://item.rakuten.co.jp/modernity/10000700/
# 8   https://item.rakuten.co.jp/plywoodfurniture/08...
# 9   https://item.rakuten.co.jp/citron-g/z204169047...
# 10  https://item.rakuten.co.jp/xiaomiauthorizedsto...
# 11    https://item.rakuten.co.jp/ebest/6934177724138/
# 12  https://item.rakuten.co.jp/gadgetmart/69341777...
# 13  https://item.rakuten.co.jp/r-kojima/6934177724...
# 14  https://item.rakuten.co.jp/biccamera/693417771...
# 15    https://item.rakuten.co.jp/ebest/6934177712685/
# 16         https://item.rakuten.co.jp/stab-blue/6274/
# 17  https://item.rakuten.co.jp/yamada-denki/139241...
# 18  https://item.rakuten.co.jp/plywoodzakka/08637001/
# 19  https://item.rakuten.co.jp/boutiquedebonheur/b...
#
#                                           description   price score
# 0   空気清浄機 30畳 Googleアシスタント アレクサー対応 スマホ連動可 花粉症 PM2....   19900     5
# 1   【お得な 2個組】USB空気清浄機 ミニ 車載用 車内マイナスイオン発生器 小型脱臭機 US...    1880   3.5
# 2   【公式】BRIIV Air Purifier [ブリーヴ] 英国発・自然を愛するサステナブル...   69850     0
# 3   Xiaomi 空気清浄機 専用 フィルター Mi Air Purifier HEPA Fil...    3990  4.43
# 4   Xiaomi Mi 空気清浄機 3H Mi Air Purifier 3H 30畳まで対応 ...   19900  4.68
# 5   【特典付き】cado 空気清浄機 LEAF720 AP-C720 カドー正規販売店 リーフ7...  139700  4.82
# 6   【マラソン期間中 最大P48倍】プラスマイナスゼロ プラマイゼロ【あす楽14時まで】±0 A...    4400  4.29
# 7   【公式】BRIIV Air Purifier [ブリーヴ] 英国発・自然を愛するサステナブル...   69850     0
# 8   【マラソン期間中 最大P39倍】プラスマイナスゼロ 空気清浄機 【あす楽14時まで】【送料無...   17600     4
# 9   【送料無料】プラスマイナスゼロ ±0 空気清浄機 Air Purifier ホワイト XQH...   17600     5
# 10  空気清浄機 30畳 Googleアシスタント アレクサー対応 スマホ連動可 花粉症 PM2....   19900     5
# 11  シャオミ 小米 AC-M6-SC MI Air Purifier 3H 空気清浄機 14〜2...   19900     0
# 12  Xiaomi シャオミ Mi 空気清浄機 3H MI Air Purifier HEPA F...   19900     0
# 13      XIAOMI シャオミ 空間清浄機 Mi Air Purifier 3H AC-M6-SC   19900     0
# 14    Xiaomi｜シャオミ Mi Air Purifier HEPA Filter M8R-FLH    4080     0
# 15  シャオミ 小米 M8R-FLH MI Air Purifier 空気清浄機用HEPAフィルタ...    4500     0
# 16  Mini Air Purifier ミニ エアー ピュリファイヤー 空気清浄機 マイナスイオ...    5280     0
# 17  Xiaomi シャオミ エコプロダクト Mi Air Purifier 3H White A...   19900     5
# 18  【マラソン期間中 最大P39倍】プラスマイナスゼロ 空気清浄機 【あす楽14時まで】【送料無...   17600     5
# 19  【お買い物マラソン先着5名様限定15%OFFクーポン対象】【本日ポイント5倍】【あす楽】30...    1980  4.78

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1051, step=1)

# %%
df.tail()
# Out:
#                                                     url  \
# 1046  https://item.rakuten.co.jp/cross-one/cross-one...
# 1047        https://item.rakuten.co.jp/un-limit/815568/
# 1048            https://item.rakuten.co.jp/siroca/p230/
# 1049        https://item.rakuten.co.jp/un-limit/813635/
# 1050  https://item.rakuten.co.jp/omatsuri-life2/b01n...
#
#                                             description   price score
# 1046  車用空気清浄機 PHLIPS Go Pure Car air purifier GPC10MXX1    9250     0
# 1047  Rabbit Air ラビットエアー AIR PURIFIER MinusA2 WiFiモデ...   74580     0
# 1048  BONECO P230 AIR PURIFIER [空気清浄機/コンパクト/強力/簡単操作/...   17800     0
# 1049  cado カドー AIR PURIFIER LEAF 320i AP-C200交換用フィルタ...    7975     0
# 1050  【中古】Sharp KC-850U Plasmacluster Air Purifier w...  165498     0

# %%
df.to_csv('rekuten1007.csv',  encoding='utf-16')
